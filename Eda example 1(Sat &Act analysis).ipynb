# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sat_17 = pd.read_csv('./data/sat_2017.csv')
sat_18 = pd.read_csv('./data/sat_2018.csv')
act_17 = pd.read_csv('./data/act_2017.csv')
act_18 = pd.read_csv('./data/act_2018.csv')

# %%
print("SAT 2017 shape = ", sat_17.shape)
print("SAT 2018 shape = ", sat_18.shape)
print("ACT 2017 shape = ", act_17.shape)
print("ACT 2018 shape = ", act_18.shape)
# Out:
# SAT 2017 shape =  (51, 5)
# SAT 2018 shape =  (51, 5)
# ACT 2017 shape =  (52, 7)
# ACT 2018 shape =  (53, 3)

# %%
act_17.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
act_18.head()
# Out:
#            State Participation Composite
# 0          Maine            7%        24
# 1   Rhode Island           15%      24.2
# 2  New Hampshire           16%      25.1
# 3       Delaware           17%      23.8
# 4   Pennsylvania           20%      23.5

# %%
sat_17.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
sat_18.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
act_18['State'].counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-d60912e80b02> in <module>
# ----> 1 act_18['State'].counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'counts'

# %%
act_18['State'].value_counts()
# Out:
# Maine               2
# Mississippi         1
# Maryland            1
# Kentucky            1
# Tennessee           1
# Arizona             1
# New Hampshire       1
# Vermont             1
# Arkansas            1
# South Dakota        1
# Michigan            1
# Washington, D.C.    1
# Louisiana           1
# Rhode Island        1
# North Dakota        1
# Kansas              1
# Oregon              1
# Virginia            1
# Wyoming             1
# New Mexico          1
# Florida             1
# Iowa                1
# Montana             1
# Georgia             1
# Alaska              1
# Texas               1
# New York            1
# Alabama             1
# Indiana             1
# South Carolina      1
# New Jersey          1
# Illinois            1
# Hawaii              1
# California          1
# Delaware            1
# Colorado            1
# Utah                1
# Oklahoma            1
# Nebraska            1
# Idaho               1
# Washington          1
# Missouri            1
# Massachusetts       1
# Wisconsin           1
# North Carolina      1
# Pennsylvania        1
# Nevada              1
# Connecticut         1
# Minnesota           1
# West Virginia       1
# Ohio                1
# National            1
# Name: State, dtype: int64

# %%
act_18.groupby("State")['State'].count()
# Out:
# State
# Alabama             1
# Alaska              1
# Arizona             1
# Arkansas            1
# California          1
# Colorado            1
# Connecticut         1
# Delaware            1
# Florida             1
# Georgia             1
# Hawaii              1
# Idaho               1
# Illinois            1
# Indiana             1
# Iowa                1
# Kansas              1
# Kentucky            1
# Louisiana           1
# Maine               2
# Maryland            1
# Massachusetts       1
# Michigan            1
# Minnesota           1
# Mississippi         1
# Missouri            1
# Montana             1
# National            1
# Nebraska            1
# Nevada              1
# New Hampshire       1
# New Jersey          1
# New Mexico          1
# New York            1
# North Carolina      1
# North Dakota        1
# Ohio                1
# Oklahoma            1
# Oregon              1
# Pennsylvania        1
# Rhode Island        1
# South Carolina      1
# South Dakota        1
# Tennessee           1
# Texas               1
# Utah                1
# Vermont             1
# Virginia            1
# Washington          1
# Washington, D.C.    1
# West Virginia       1
# Wisconsin           1
# Wyoming             1
# Name: State, dtype: int64

# %%
act_18[act_18['State'] == 'Maine']
# Out:
#     State Participation Composite
# 0   Maine            7%        24
# 52  Maine            7%        24

# %%
act_18.drop(act_18.index[52], inplace=True)

# %%
act_18
# Out:
#                State Participation Composite
# 0              Maine            7%        24
# 1       Rhode Island           15%      24.2
# 2      New Hampshire           16%      25.1
# 3           Delaware           17%      23.8
# 4       Pennsylvania           20%      23.5
# 5           Michigan           22%      24.2
# 6            Vermont           24%      24.1
# 7           Virginia           24%      23.9
# 8         Washington           24%      22.2
# 9      Massachusetts           25%      25.5
# 10       Connecticut           26%      25.6
# 11        California           27%      22.7
# 12          New York           27%      24.5
# 13          Colorado           30%      23.9
# 14          Maryland           31%      22.5
# 15        New Jersey           31%      23.7
# 16  Washington, D.C.           32%      23.6
# 17           Indiana           32%      22.5
# 18            Alaska           33%      20.8
# 19             Idaho           36%      22.3
# 20            Oregon           42%      21.3
# 21          Illinois           43%      23.9
# 22             Texas           45%      20.7
# 23          National           50%     #REF!
# 24           Georgia           53%      21.4
# 25     West Virginia           65%      20.3
# 26           Arizona           66%      19.2
# 27           Florida           66%      19.9
# 28        New Mexico           67%      19.4
# 29              Iowa           68%      21.8
# 30            Kansas           71%      21.6
# 31      South Dakota           77%      21.9
# 32            Hawaii           89%      18.9
# 33      North Dakota           98%      20.3
# 34         Minnesota           99%      21.3
# 35           Alabama          100%      19.1
# 36          Arkansas          100%      19.4
# 37          Kentucky          100%      20.2
# 38         Louisiana          100%      19.2
# 39       Mississippi          100%      18.6
# 40          Missouri          100%        20
# 41           Montana          100%        20
# 42          Nebraska          100%      20.1
# 43            Nevada          100%      17.7
# 44    North Carolina          100%      19.1
# 45              Ohio          100%      20.3
# 46          Oklahoma          100%      19.3
# 47    South Carolina          100%      18.3
# 48         Tennessee          100%      19.6
# 49              Utah          100%      20.4
# 50         Wisconsin          100%      20.5
# 51           Wyoming          100%        20

# %%
act_18.shape
# Out:
# (52, 3)

# %%
at17 = act_17['State']

# %%
at18 = act_18['State']

# %%
st17 = sat_17["State"]

# %%
comparison_col = np.where(new == ,True, False)
print( comparison_col)
# Out:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]

# %%
new = pd.merge(st17,at17, how = "inner")
new
# Out:
#                    State
# 0                Alabama
# 1                 Alaska
# 2                Arizona
# 3               Arkansas
# 4             California
# 5               Colorado
# 6            Connecticut
# 7               Delaware
# 8   District of Columbia
# 9                Florida
# 10               Georgia
# 11                Hawaii
# 12                 Idaho
# 13              Illinois
# 14               Indiana
# 15                  Iowa
# 16                Kansas
# 17              Kentucky
# 18             Louisiana
# 19                 Maine
# 20              Maryland
# 21         Massachusetts
# 22              Michigan
# 23             Minnesota
# 24           Mississippi
# 25              Missouri
# 26               Montana
# 27              Nebraska
# 28                Nevada
# 29         New Hampshire
# 30            New Jersey
# 31            New Mexico
# 32              New York
# 33        North Carolina
# 34          North Dakota
# 35                  Ohio
# 36              Oklahoma
# 37                Oregon
# 38          Pennsylvania
# 39          Rhode Island
# 40        South Carolina
# 41          South Dakota
# 42             Tennessee
# 43                 Texas
# 44                  Utah
# 45               Vermont
# 46              Virginia
# 47            Washington
# 48         West Virginia
# 49             Wisconsin
# 50               Wyoming

# %%
comparison_col = np.where(new == at18 ,True, False)
print( comparison_col)
new["comp"] = comparison_col
print(new)
# Out:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'comp'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in set(self, item, value)
#    1070         try:
# -> 1071             loc = self.items.get_loc(item)
#    1072         except KeyError:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'comp'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-4d36ea9cec4f> in <module>
#       1 comparison_col = np.where(new == at18 ,True, False)
#       2 print( comparison_col)
# ----> 3 new["comp"] = comparison_col
#       4 print(new)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2999         self._ensure_valid_index(value)
#    3000         value = self._sanitize_column(key, value)
# -> 3001         NDFrame._set_item(self, key, value)
#    3002
#    3003         # check if we are modifying a copy
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
#    3622
#    3623     def _set_item(self, key, value) -> None:
# -> 3624         self._data.set(key, value)
#    3625         self._clear_item_cache()
#    3626
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in set(self, item, value)
#    1072         except KeyError:
#    1073             # This item wasn't present, just insert at end
# -> 1074             self.insert(len(self.items), item, value)
#    1075             return
#    1076
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1179         new_axis = self.items.insert(loc, item)
#    1180
# -> 1181         block = make_block(values=value, ndim=self.ndim, placement=slice(loc, loc + 1))
#    1182
#    1183         for blkno, count in _fast_count_smallints(self._blknos[loc:]):
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    3039         values = DatetimeArray._simple_new(values, dtype=dtype)
#    3040
# -> 3041     return klass(values, ndim=ndim, placement=placement)
#    3042
#    3043
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     123         if self._validate_ndim and self.ndim and len(self.mgr_locs) != len(self.values):
#     124             raise ValueError(
# --> 125                 f"Wrong number of items passed {len(self.values)}, "
#     126                 f"placement implies {len(self.mgr_locs)}"
#     127             )
#
# ValueError: Wrong number of items passed 53, placement implies 1

# %%
pd.merge(at17,at18, how = "inner")
# Out:
#              State
# 0         National
# 1          Alabama
# 2           Alaska
# 3          Arizona
# 4         Arkansas
# 5       California
# 6         Colorado
# 7      Connecticut
# 8         Delaware
# 9          Florida
# 10         Georgia
# 11          Hawaii
# 12           Idaho
# 13        Illinois
# 14         Indiana
# 15            Iowa
# 16          Kansas
# 17        Kentucky
# 18       Louisiana
# 19           Maine
# 20        Maryland
# 21   Massachusetts
# 22        Michigan
# 23       Minnesota
# 24     Mississippi
# 25        Missouri
# 26         Montana
# 27        Nebraska
# 28          Nevada
# 29   New Hampshire
# 30      New Jersey
# 31      New Mexico
# 32        New York
# 33  North Carolina
# 34    North Dakota
# 35            Ohio
# 36        Oklahoma
# 37          Oregon
# 38    Pennsylvania
# 39    Rhode Island
# 40  South Carolina
# 41    South Dakota
# 42       Tennessee
# 43           Texas
# 44            Utah
# 45         Vermont
# 46        Virginia
# 47      Washington
# 48   West Virginia
# 49       Wisconsin
# 50         Wyoming

# %%
act_18.shape
# Out:
# (52, 3)

# %%
act_v8 = act_17["State"]

# %%
act_v = act_18["State"]

# %%
for ty in act_v:
    if (ty  not in act_v8):
         print(ty)
# Out:
# Maine
# Rhode Island
# New Hampshire
# Delaware
# Pennsylvania
# Michigan
# Vermont
# Virginia
# Washington
# Massachusetts
# Connecticut
# California
# New York
# Colorado
# Maryland
# New Jersey
# Washington, D.C.
# Indiana
# Alaska
# Idaho
# Oregon
# Illinois
# Texas
# National
# Georgia
# West Virginia
# Arizona
# Florida
# New Mexico
# Iowa
# Kansas
# South Dakota
# Hawaii
# North Dakota
# Minnesota
# Alabama
# Arkansas
# Kentucky
# Louisiana
# Mississippi
# Missouri
# Montana
# Nebraska
# Nevada
# North Carolina
# Ohio
# Oklahoma
# South Carolina
# Tennessee
# Utah
# Wisconsin
# Wyoming

# %%
act_18["State"]
# Out:
# 0                Maine
# 1         Rhode Island
# 2        New Hampshire
# 3             Delaware
# 4         Pennsylvania
# 5             Michigan
# 6              Vermont
# 7             Virginia
# 8           Washington
# 9        Massachusetts
# 10         Connecticut
# 11          California
# 12            New York
# 13            Colorado
# 14            Maryland
# 15          New Jersey
# 16    Washington, D.C.
# 17             Indiana
# 18              Alaska
# 19               Idaho
# 20              Oregon
# 21            Illinois
# 22               Texas
# 23            National
# 24             Georgia
# 25       West Virginia
# 26             Arizona
# 27             Florida
# 28          New Mexico
# 29                Iowa
# 30              Kansas
# 31        South Dakota
# 32              Hawaii
# 33        North Dakota
# 34           Minnesota
# 35             Alabama
# 36            Arkansas
# 37            Kentucky
# 38           Louisiana
# 39         Mississippi
# 40            Missouri
# 41             Montana
# 42            Nebraska
# 43              Nevada
# 44      North Carolina
# 45                Ohio
# 46            Oklahoma
# 47      South Carolina
# 48           Tennessee
# 49                Utah
# 50           Wisconsin
# 51             Wyoming
# Name: State, dtype: object

# %%
def compare_values(act_col, sat_col):
    
    act_vals = []
    sat_vals = []
    
    for a_val in act_col:
        act_vals.append(a_val)
        
    for s_val in sat_col:
        sat_vals.append(s_val)
        
    print("The values in act only ")
       
    for a_v in act_vals:
        if(a_v not in sat_vals):
            print(a_v)
           
       
    print('The values in sat only')
    
    for s_v in sat_vals:
        if(s_v not in act_vals):
            print(s_v)

# %%
compare_values(act_17["state"], sat_17["state"])
# Out:
# The values in act only
# The values in sat only
# Alabama

# %%
compare_values(act_18["State"], sat_18["State"])
# Out:
# The values in act only
# Washington, D.C.
# National
# The values in sat only
# District of Columbia

# %%
act_17[act_17["State"] == "National"]
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0

# %%
act_17.drop(act_17.index[0], inplace=True)

# %%
act_17 = act_17.reset_index(drop=True)
act_17
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     403                         if cls is not object \
#     404                                 and callable(cls.__dict__.get('__repr__')):
# --> 405                             return _repr_pprint(obj, self, cycle)
#     406
#     407             return _default_pprint(obj, self, cycle)
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
#     693     """A pprint that just redirects to the normal repr function."""
#     694     # Find newlines and replace them with p.break_()
# --> 695     output = repr(obj)
#     696     lines = output.splitlines()
#     697     with p.group():
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __repr__(self)
#     685             line_width=width,
#     686             max_colwidth=max_colwidth,
# --> 687             show_dimensions=show_dimensions,
#     688         )
#     689
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, min_rows, max_cols, show_dimensions, decimal, line_width, max_colwidth, encoding)
#     818                 line_width=line_width,
#     819             )
# --> 820             return formatter.to_string(buf=buf, encoding=encoding)
#     821
#     822     # ----------------------------------------------------------------------
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_string(self, buf, encoding)
#     914         encoding: Optional[str] = None,
#     915     ) -> Optional[str]:
# --> 916         return self.get_result(buf=buf, encoding=encoding)
#     917
#     918     def to_latex(
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in get_result(self, buf, encoding)
#     521         """
#     522         with self.get_buffer(buf, encoding=encoding) as f:
# --> 523             self.write_result(buf=f)
#     524             if buf is None:
#     525                 return f.getvalue()
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in write_result(self, buf)
#     823         else:
#     824
# --> 825             strcols = self._to_str_columns()
#     826             if self.line_width is None:  # no need to wrap around just print
#     827                 # the whole frame
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in _to_str_columns(self)
#     759                     self.col_space or 0, *(self.adj.len(x) for x in cheader)
#     760                 )
# --> 761                 fmt_values = self._format_col(i)
#     762                 fmt_values = _make_fixed_width(
#     763                     fmt_values, self.justify, minimum=header_colwidth, adj=self.adj
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in _format_col(self, i)
#     954             na_rep=self.na_rep,
#     955             space=self.col_space,
# --> 956             decimal=self.decimal,
#     957         )
#     958
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space)
#    1172     )
#    1173
# -> 1174     return fmt_obj.get_result()
#    1175
#    1176
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in get_result(self)
#    1203
#    1204     def get_result(self) -> List[str]:
# -> 1205         fmt_values = self._format_strings()
#    1206         return _make_fixed_width(fmt_values, self.justify)
#    1207
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in _format_strings(self)
#    1268                 else:
#    1269                     tpl = " {v}"
# -> 1270                 fmt_values.append(tpl.format(v=_format(v)))
#    1271
#    1272         return fmt_values
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in _format(x)
#    1242             else:
#    1243                 # object dtype
# -> 1244                 return "{x}".format(x=formatter(x))
#    1245
#    1246         vals = self.values
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in <lambda>(x)
#    1220             self.formatter
#    1221             if self.formatter is not None
# -> 1222             else (lambda x: pprint_thing(x, escape_chars=("\t", "\r", "\n")))
#    1223         )
#    1224
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\printing.py in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     228         result = "'{thing}'".format(thing=as_escaped_string(thing))
#     229     else:
# --> 230         result = as_escaped_string(thing)
#     231
#     232     return result
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\printing.py in as_escaped_string(thing, escape_chars)
#     204             escape_chars = escape_chars or tuple()
#     205
# --> 206         result = str(thing)
#     207         for c in escape_chars:
#     208             result = result.replace(c, translate[c])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __repr__(self)
#    1369             min_rows=min_rows,
#    1370             max_rows=max_rows,
# -> 1371             length=show_dimensions,
#    1372         )
#    1373         result = buf.getvalue()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1435             max_rows=max_rows,
#    1436         )
# -> 1437         result = formatter.to_string()
#    1438
#    1439         # catch contract violations
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_string(self)
#     359
#     360         fmt_index, have_header = self._get_formatted_index()
# --> 361         fmt_values = self._get_formatted_values()
#     362
#     363         if self.truncate_v:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in _get_formatted_values(self)
#     346             None,
#     347             float_format=self.float_format,
# --> 348             na_rep=self.na_rep,
#     349         )
#     350
#
# ... last 11 frames repeated, from the frame below ...
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space)
#    1172     )
#    1173
# -> 1174     return fmt_obj.get_result()
#    1175
#    1176
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _repr_html_(self)
#     732                 render_links=False,
#     733             )
# --> 734             return formatter.to_html(notebook=True)
#     735         else:
#     736             return None
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_html(self, buf, encoding, classes, notebook, border)
#     983         Klass = NotebookFormatter if notebook else HTMLFormatter
#     984         return Klass(self, classes=classes, border=border).get_result(
# --> 985             buf=buf, encoding=encoding
#     986         )
#     987
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in get_result(self, buf, encoding)
#     521         """
#     522         with self.get_buffer(buf, encoding=encoding) as f:
# --> 523             self.write_result(buf=f)
#     524             if buf is None:
#     525                 return f.getvalue()
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\html.py in write_result(self, buf)
#     205
#     206     def write_result(self, buf: IO[str]) -> None:
# --> 207         buffer_put_lines(buf, self.render())
#     208
#     209     def _write_table(self, indent: int = 0) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\html.py in render(self)
#     610         self.write("<div>")
#     611         self.write_style()
# --> 612         super().render()
#     613         self.write("</div>")
#     614         return self.elements
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\html.py in render(self)
#     192
#     193     def render(self) -> List[str]:
# --> 194         self._write_table()
#     195
#     196         if self.should_show_dimensions:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\html.py in _write_table(self, indent)
#     237             self._write_header(indent + self.indent_delta)
#     238
# --> 239         self._write_body(indent + self.indent_delta)
#     240
#     241         self.write("</table>", indent)
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\html.py in _write_body(self, indent)
#     383     def _write_body(self, indent: int) -> None:
#     384         self.write("<tbody>", indent)
# --> 385         fmt_values = self._get_formatted_values()
#     386
#     387         # write values
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\html.py in _get_formatted_values(self)
#     574
#     575     def _get_formatted_values(self) -> Dict[int, List[str]]:
# --> 576         return {i: self.fmt._format_col(i) for i in range(self.ncols)}
#     577
#     578     def _get_columns_formatted_values(self) -> List[str]:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\html.py in <dictcomp>(.0)
#     574
#     575     def _get_formatted_values(self) -> Dict[int, List[str]]:
# --> 576         return {i: self.fmt._format_col(i) for i in range(self.ncols)}
#     577
#     578     def _get_columns_formatted_values(self) -> List[str]:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in _format_col(self, i)
#     954             na_rep=self.na_rep,
#     955             space=self.col_space,
# --> 956             decimal=self.decimal,
#     957         )
#     958
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space)
#    1172     )
#    1173
# -> 1174     return fmt_obj.get_result()
#    1175
#    1176
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in get_result(self)
#    1203
#    1204     def get_result(self) -> List[str]:
# -> 1205         fmt_values = self._format_strings()
#    1206         return _make_fixed_width(fmt_values, self.justify)
#    1207
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in _format_strings(self)
#    1268                 else:
#    1269                     tpl = " {v}"
# -> 1270                 fmt_values.append(tpl.format(v=_format(v)))
#    1271
#    1272         return fmt_values
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in _format(x)
#    1242             else:
#    1243                 # object dtype
# -> 1244                 return "{x}".format(x=formatter(x))
#    1245
#    1246         vals = self.values
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in <lambda>(x)
#    1220             self.formatter
#    1221             if self.formatter is not None
# -> 1222             else (lambda x: pprint_thing(x, escape_chars=("\t", "\r", "\n")))
#    1223         )
#    1224
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\printing.py in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     228         result = "'{thing}'".format(thing=as_escaped_string(thing))
#     229     else:
# --> 230         result = as_escaped_string(thing)
#     231
#     232     return result
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\printing.py in as_escaped_string(thing, escape_chars)
#     204             escape_chars = escape_chars or tuple()
#     205
# --> 206         result = str(thing)
#     207         for c in escape_chars:
#     208             result = result.replace(c, translate[c])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __repr__(self)
#    1369             min_rows=min_rows,
#    1370             max_rows=max_rows,
# -> 1371             length=show_dimensions,
#    1372         )
#    1373         result = buf.getvalue()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1435             max_rows=max_rows,
#    1436         )
# -> 1437         result = formatter.to_string()
#    1438
#    1439         # catch contract violations
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_string(self)
#     359
#     360         fmt_index, have_header = self._get_formatted_index()
# --> 361         fmt_values = self._get_formatted_values()
#     362
#     363         if self.truncate_v:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in _get_formatted_values(self)
#     346             None,
#     347             float_format=self.float_format,
# --> 348             na_rep=self.na_rep,
#     349         )
#     350
#
# ... last 11 frames repeated, from the frame below ...
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space)
#    1172     )
#    1173
# -> 1174     return fmt_obj.get_result()
#    1175
#    1176
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
act_18[act_18["State"]=="Maine"]
# Out:
#     State Participation Composite
# 0   Maine             7        24
# 51  Maine             7        24

# %%
act_18.drop(act_18.index[51],inplace=True)
act_18 = act_18.reset_index(drop=True)

# %%
act_18.count()
# Out:
# State            51
# Participation    51
# Composite        51
# dtype: int64

# %%
compare_values(act_18["State"], sat_18["State"])
# Out:
# The values in act only
# The values in sat only

# %%
compare_values(act_17["State"], sat_17["State"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'State'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-271-f0896974c6e0> in <module>
# ----> 1 compare_values(act_17["State"], sat_17["State"])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'State'

# %%
act_17[act_17["State"]=="Washington, D.C."]
# Out:
# Empty DataFrame
# Columns: [State, Participation, English, Math, Reading, Science, Composite]
# Index: []

# %%
 act_17['Composite'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1797     def __hash__(self):
#    1798         raise TypeError(
# -> 1799             f"{repr(type(self).__name__)} objects are mutable, "
#    1800             f"thus they cannot be hashed"
#    1801         )
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
#   File "C:\Users\agbaj\anaconda3\lib\site-packages\pandas\core\generic.py", line 1799, in __hash__
#     f"{repr(type(self).__name__)} objects are mutable, "
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     403                         if cls is not object \
#     404                                 and callable(cls.__dict__.get('__repr__')):
# --> 405                             return _repr_pprint(obj, self, cycle)
#     406
#     407             return _default_pprint(obj, self, cycle)
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
#     693     """A pprint that just redirects to the normal repr function."""
#     694     # Find newlines and replace them with p.break_()
# --> 695     output = repr(obj)
#     696     lines = output.splitlines()
#     697     with p.group():
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __repr__(self)
#    1369             min_rows=min_rows,
#    1370             max_rows=max_rows,
# -> 1371             length=show_dimensions,
#    1372         )
#    1373         result = buf.getvalue()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1435             max_rows=max_rows,
#    1436         )
# -> 1437         result = formatter.to_string()
#    1438
#    1439         # catch contract violations
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_string(self)
#     358             )
#     359
# --> 360         fmt_index, have_header = self._get_formatted_index()
#     361         fmt_values = self._get_formatted_values()
#     362
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in _get_formatted_index(self)
#     338         else:
#     339             have_header = index.name is not None
# --> 340             fmt_index = index.format(name=True)
#     341         return fmt_index, have_header
#     342
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in format(self, name, formatter, **kwargs)
#     964             return header + list(self.map(formatter))
#     965
# --> 966         return self._format_with_header(header, **kwargs)
#     967
#     968     def _format_with_header(self, header, na_rep="NaN", **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _format_with_header(self, header, na_rep, **kwargs)
#     978
#     979         if is_object_dtype(values.dtype):
# --> 980             result = [pprint_thing(x, escape_chars=("\t", "\r", "\n")) for x in values]
#     981
#     982             # could have nans
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in <listcomp>(.0)
#     978
#     979         if is_object_dtype(values.dtype):
# --> 980             result = [pprint_thing(x, escape_chars=("\t", "\r", "\n")) for x in values]
#     981
#     982             # could have nans
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\printing.py in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     228         result = "'{thing}'".format(thing=as_escaped_string(thing))
#     229     else:
# --> 230         result = as_escaped_string(thing)
#     231
#     232     return result
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\printing.py in as_escaped_string(thing, escape_chars)
#     204             escape_chars = escape_chars or tuple()
#     205
# --> 206         result = str(thing)
#     207         for c in escape_chars:
#     208             result = result.replace(c, translate[c])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __repr__(self)
#    1369             min_rows=min_rows,
#    1370             max_rows=max_rows,
# -> 1371             length=show_dimensions,
#    1372         )
#    1373         result = buf.getvalue()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows, min_rows)
#    1435             max_rows=max_rows,
#    1436         )
# -> 1437         result = formatter.to_string()
#    1438
#    1439         # catch contract violations
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_string(self)
#     359
#     360         fmt_index, have_header = self._get_formatted_index()
# --> 361         fmt_values = self._get_formatted_values()
#     362
#     363         if self.truncate_v:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in _get_formatted_values(self)
#     346             None,
#     347             float_format=self.float_format,
# --> 348             na_rep=self.na_rep,
#     349         )
#     350
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal, leading_space)
#    1172     )
#    1173
# -> 1174     return fmt_obj.get_result()
#    1175
#    1176
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in get_result(self)
#    1203
#    1204     def get_result(self) -> List[str]:
# -> 1205         fmt_values = self._format_strings()
#    1206         return _make_fixed_width(fmt_values, self.justify)
#    1207
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in _format_strings(self)
#    1268                 else:
#    1269                     tpl = " {v}"
# -> 1270                 fmt_values.append(tpl.format(v=_format(v)))
#    1271
#    1272         return fmt_values
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in _format(x)
#    1242             else:
#    1243                 # object dtype
# -> 1244                 return "{x}".format(x=formatter(x))
#    1245
#    1246         vals = self.values
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in <lambda>(x)
#    1220             self.formatter
#    1221             if self.formatter is not None
# -> 1222             else (lambda x: pprint_thing(x, escape_chars=("\t", "\r", "\n")))
#    1223         )
#    1224
#
# ... last 11 frames repeated, from the frame below ...
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\printing.py in pprint_thing(thing, _nest_lvl, escape_chars, default_escapes, quote_strings, max_seq_items)
#     228         result = "'{thing}'".format(thing=as_escaped_string(thing))
#     229     else:
# --> 230         result = as_escaped_string(thing)
#     231
#     232     return result
#
# RecursionError: maximum recursion depth exceeded

# %%
act_17 = pd.read_csv('./data/act_2017.csv')

# %%
act_17
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# 12                Hawaii           90%     17.8  19.2     19.2     19.3
# 13                 Idaho           38%     21.9  21.8     23.0     22.1
# 14              Illinois           93%     21.0  21.2     21.6     21.3
# 15               Indiana           35%     22.0  22.4     23.2     22.3
# 16                  Iowa           67%     21.2  21.3     22.6     22.1
# 17                Kansas           73%     21.1  21.3     22.3     21.7
# 18              Kentucky          100%     19.6  19.4     20.5     20.1
# 19             Louisiana          100%     19.4  18.8     19.8     19.6
# 20                 Maine            8%     24.2  24.0     24.8     23.7
# 21              Maryland           28%     23.3  23.1     24.2      2.3
# 22         Massachusetts           29%     25.4  25.3     25.9     24.7
# 23              Michigan           29%     24.1  23.7     24.5     23.8
# 24             Minnesota          100%     20.4  21.5     21.8     21.6
# 25           Mississippi          100%     18.2  18.1     18.8     18.8
# 26              Missouri          100%     19.8  19.9     20.8     20.5
# 27               Montana          100%     19.0  20.2     21.0     20.5
# 28              Nebraska           84%     20.9  20.9     21.9     21.5
# 29                Nevada          100%     16.3  18.0     18.1     18.2
# 30         New Hampshire           18%     25.4  25.1     26.0     24.9
# 31            New Jersey           34%     23.8  23.8     24.1     23.2
# 32            New Mexico           66%     18.6  19.4     20.4     20.0
# 33              New York           31%     23.8  24.0     24.6     23.9
# 34        North Carolina          100%     17.8  19.3     19.6     19.3
# 35          North Dakota           98%     19.0  20.4     20.5     20.6
# 36                  Ohio           75%     21.2  21.6     22.5     22.0
# 37              Oklahoma          100%     18.5  18.8     20.1     19.6
# 38                Oregon           40%     21.2  21.5     22.4     21.7
# 39          Pennsylvania           23%     23.4  23.4     24.2     23.3
# 40          Rhode Island           21%     24.0  23.3     24.7     23.4
# 41        South Carolina          100%     17.5  18.6     19.1     18.9
# 42          South Dakota           80%     20.7  21.5     22.3     22.0
# 43             Tennessee          100%     19.5  19.2     20.1     19.9
# 44                 Texas           45%     19.5  20.7     21.1     20.9
# 45                  Utah          100%     19.5  19.9     20.8     20.6
# 46               Vermont           29%     23.3  23.1     24.4     23.2
# 47              Virginia           29%     23.5  23.3     24.6     23.5
# 48            Washington           29%     20.9  21.9     22.1     22.0
# 49         West Virginia           69%     20.0  19.4     21.2     20.5
# 50             Wisconsin          100%     19.7  20.4     20.6     20.9
# 51               Wyoming          100%     19.4  19.8     20.8     20.6
#
#    Composite
# 0       21.0
# 1       19.2
# 2       19.8
# 3       19.7
# 4       19.4
# 5       22.8
# 6       20.8
# 7       25.2
# 8       24.1
# 9       24.2
# 10      19.8
# 11      21.4
# 12      19.0
# 13      22.3
# 14      21.4
# 15      22.6
# 16      21.9
# 17      21.7
# 18      20.0
# 19      19.5
# 20      24.3
# 21      23.6
# 22      25.4
# 23      24.1
# 24      21.5
# 25      18.6
# 26      20.4
# 27      20.3
# 28      21.4
# 29      17.8
# 30      25.5
# 31      23.9
# 32      19.7
# 33      24.2
# 34      19.1
# 35      20.3
# 36      22.0
# 37      19.4
# 38      21.8
# 39      23.7
# 40      24.0
# 41      18.7
# 42      21.8
# 43      19.8
# 44      20.7
# 45      20.3
# 46      23.6
# 47      23.8
# 48      21.9
# 49      20.4
# 50      20.5
# 51     20.2x

# %%
act_18["State"].replace({"Washington, D.C.":"District of Columbia"}, inplace=)

# %%
compare_values(act_18["State"], sat_18["State"])
# Out:
# The values in act only
# The values in sat only

# %%
print("SAT 2017 column names = ", sat_17.columns, "\n")
print("SAT 2018 column names = ", sat_18.columns, "\n")
print("ACT 2017 column names = ", act_17.columns, "\n")
print("ACT 2018 column names = ", act_18.columns, "\n")
# Out:
# SAT 2017 column names =  Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')
#
# SAT 2018 column names =  Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')
#
# ACT 2017 column names =  Index(['State', 'Participation', 'English', 'Math', 'Reading', 'Science',
#        'Composite'],
#       dtype='object')
#
# ACT 2018 column names =  Index(['State', 'Participation', 'Composite'], dtype='object')

# %%
sat_17.drop(columns =['Evidence-Based Reading and Writing', 'Math'], inplace= True)
sat_18.drop(columns =['Evidence-Based Reading and Writing', 'Math'], inplace = True)
act_17.drop(columns = ['English', 'Math', 'Reading', 'Science'], inplace = True)

# %%
print("SAT 2017 column names = ", sat_17.columns, "\n")
print("SAT 2018 column names = ", sat_18.columns, "\n")
print("ACT 2017 column names = ", act_17.columns, "\n")
print("ACT 2018 column names = ", act_18.columns, "\n")
# Out:
# SAT 2017 column names =  Index(['State', 'Participation', 'Total'], dtype='object')
#
# SAT 2018 column names =  Index(['State', 'Participation', 'Total'], dtype='object')
#
# ACT 2017 column names =  Index(['State', 'Participation', 'Composite'], dtype='object')
#
# ACT 2018 column names =  Index(['State', 'Participation', 'Composite'], dtype='object')

# %%
print("SAT 2017 Missing Data: ")
print(sat_17.isnull().sum(), "\n")
print("SAT 2018 Missing Data: ")
print(sat_18.isnull().sum(), "\n")
print("ACT 2017 Missing Data: ")
print(act_17.isnull().sum(), "\n")
print("ACT 2018 Missing Data: ")
print(act_18.isnull().sum(), "\n")
# Out:
# SAT 2017 Missing Data:
# State            0
# Participation    0
# Total            0
# dtype: int64
#
# SAT 2018 Missing Data:
# State            0
# Participation    0
# Total            0
# dtype: int64
#
# ACT 2017 Missing Data:
# State            0
# Participation    0
# Composite        0
# dtype: int64
#
# ACT 2018 Missing Data:
# State            0
# Participation    0
# Composite        0
# dtype: int64

# %%
print("SAT 2017 Data Types: ")
print(sat_17.dtypes, "\n")
print("SAT 2018 Data Types: ")
print(sat_18.dtypes, "\n")
print("ACT 2017 Data Types: ")
print(act_17.dtypes, "\n")
print("ACT 2018 Data Types: ")
print(act_18.dtypes, "\n")
# Out:
# SAT 2017 Data Types:
# State            object
# Participation    object
# Total             int64
# dtype: object
#
# SAT 2018 Data Types:
# State            object
# Participation    object
# Total             int64
# dtype: object
#
# ACT 2017 Data Types:
# State            object
# Participation    object
# Composite        object
# dtype: object
#
# ACT 2018 Data Types:
# State            object
# Participation    object
# Composite        object
# dtype: object

# %%
sat_18.head()
# Out:
#         State Participation  Total
# 0     Alabama            6%   1166
# 1      Alaska           43%   1106
# 2     Arizona           29%   1149
# 3    Arkansas            5%   1169
# 4  California           60%   1076

# %%
act_18.head()
# Out:
#            State Participation Composite
# 0          Maine            7%        24
# 1   Rhode Island           15%      24.2
# 2  New Hampshire           16%      25.1
# 3       Delaware           17%      23.8
# 4   Pennsylvania           20%      23.5

# %%
act_18.columns
# Out:
# Index(['State', 'Participation', 'Composite'], dtype='object')

# %%
act_18.Composite.astype(float)
# Out:
# 0     24.0
# 1     24.2
# 2     25.1
# 3     23.8
# 4     23.5
# 5     24.2
# 6     24.1
# 7     23.9
# 8     22.2
# 9     25.5
# 10    25.6
# 11    22.7
# 12    24.5
# 13    23.9
# 14    22.5
# 15    23.7
# 16    23.6
# 17    22.5
# 18    20.8
# 19    22.3
# 20    21.3
# 21    23.9
# 22    20.7
# 23    21.4
# 24    20.3
# 25    19.2
# 26    19.9
# 27    19.4
# 28    21.8
# 29    21.6
# 30    21.9
# 31    18.9
# 32    20.3
# 33    21.3
# 34    19.1
# 35    19.4
# 36    20.2
# 37    19.2
# 38    18.6
# 39    20.0
# 40    20.0
# 41    20.1
# 42    17.7
# 43    19.1
# 44    20.3
# 45    19.3
# 46    18.3
# 47    19.6
# 48    20.4
# 49    20.5
# 50    20.0
# 51    24.0
# Name: Composite, dtype: float64

# %%
act_18.dtypes
# Out:
# State            object
# Participation    object
# Composite        object
# dtype: object

# %%
def fix_participation(column):
    return column.apply(lambda cells: cells.strip("%"))

# %%
def convert_to_float(exam_df):
    features = [col for col in exam_df.columns if col != 'State']
    exam_df[features] = exam_df[features].astype(float)
    return exam_df

# %%
sat_17['Participation'] = fix_participation(sat_17['Participation'])
sat_18['Participation'] = fix_participation(sat_18['Participation'])
act_17['Participation'] = fix_participation(act_17['Participation'])
act_18['Participation'] = fix_participation(act_18['Participation'])

# %%
act_17 = convert_to_float(act_17)
act_18 = convert_to_float(act_18)
sat_17 = convert_to_float(sat_17)
sat_18 = convert_to_float(sat_18)

# %%
act_17
# Out:
#                    State Participation Composite
# 0               National            60      21.0
# 1                Alabama           100      19.2
# 2                 Alaska            65      19.8
# 3                Arizona            62      19.7
# 4               Arkansas           100      19.4
# 5             California            31      22.8
# 6               Colorado           100      20.8
# 7            Connecticut            31      25.2
# 8               Delaware            18      24.1
# 9   District of Columbia            32      24.2
# 10               Florida            73      19.8
# 11               Georgia            55      21.4
# 12                Hawaii            90      19.0
# 13                 Idaho            38      22.3
# 14              Illinois            93      21.4
# 15               Indiana            35      22.6
# 16                  Iowa            67      21.9
# 17                Kansas            73      21.7
# 18              Kentucky           100      20.0
# 19             Louisiana           100      19.5
# 20                 Maine             8      24.3
# 21              Maryland            28      23.6
# 22         Massachusetts            29      25.4
# 23              Michigan            29      24.1
# 24             Minnesota           100      21.5
# 25           Mississippi           100      18.6
# 26              Missouri           100      20.4
# 27               Montana           100      20.3
# 28              Nebraska            84      21.4
# 29                Nevada           100      17.8
# 30         New Hampshire            18      25.5
# 31            New Jersey            34      23.9
# 32            New Mexico            66      19.7
# 33              New York            31      24.2
# 34        North Carolina           100      19.1
# 35          North Dakota            98      20.3
# 36                  Ohio            75      22.0
# 37              Oklahoma           100      19.4
# 38                Oregon            40      21.8
# 39          Pennsylvania            23      23.7
# 40          Rhode Island            21      24.0
# 41        South Carolina           100      18.7
# 42          South Dakota            80      21.8
# 43             Tennessee           100      19.8
# 44                 Texas            45      20.7
# 45                  Utah           100      20.3
# 46               Vermont            29      23.6
# 47              Virginia            29      23.8
# 48            Washington            29      21.9
# 49         West Virginia            69      20.4
# 50             Wisconsin           100      20.5
# 51               Wyoming           100      20.2

# %%
act_17 = convert_to_float(act_17)

# %%
act_17['Composite'] = act_17['Composite'].apply(lambda cells: cells.strip("x"))

# %%
act_17.drop(columns = ['English', 'Math', 'Reading', 'Science'], inplace=True)

# %%
act_17['Participation'] = act_17['Participation'].apply(lambda cells: cells.strip("%"))

# %%
act_17.drop(act_17.index[0], inplace=True)
act_17 = act_17.reset_index(drop=True)
act_17
# Out:
#                    State  Participation  Composite
# 0                Alabama          100.0       19.2
# 1                 Alaska           65.0       19.8
# 2                Arizona           62.0       19.7
# 3               Arkansas          100.0       19.4
# 4             California           31.0       22.8
# 5               Colorado          100.0       20.8
# 6            Connecticut           31.0       25.2
# 7               Delaware           18.0       24.1
# 8   District of Columbia           32.0       24.2
# 9                Florida           73.0       19.8
# 10               Georgia           55.0       21.4
# 11                Hawaii           90.0       19.0
# 12                 Idaho           38.0       22.3
# 13              Illinois           93.0       21.4
# 14               Indiana           35.0       22.6
# 15                  Iowa           67.0       21.9
# 16                Kansas           73.0       21.7
# 17              Kentucky          100.0       20.0
# 18             Louisiana          100.0       19.5
# 19                 Maine            8.0       24.3
# 20              Maryland           28.0       23.6
# 21         Massachusetts           29.0       25.4
# 22              Michigan           29.0       24.1
# 23             Minnesota          100.0       21.5
# 24           Mississippi          100.0       18.6
# 25              Missouri          100.0       20.4
# 26               Montana          100.0       20.3
# 27              Nebraska           84.0       21.4
# 28                Nevada          100.0       17.8
# 29         New Hampshire           18.0       25.5
# 30            New Jersey           34.0       23.9
# 31            New Mexico           66.0       19.7
# 32              New York           31.0       24.2
# 33        North Carolina          100.0       19.1
# 34          North Dakota           98.0       20.3
# 35                  Ohio           75.0       22.0
# 36              Oklahoma          100.0       19.4
# 37                Oregon           40.0       21.8
# 38          Pennsylvania           23.0       23.7
# 39          Rhode Island           21.0       24.0
# 40        South Carolina          100.0       18.7
# 41          South Dakota           80.0       21.8
# 42             Tennessee          100.0       19.8
# 43                 Texas           45.0       20.7
# 44                  Utah          100.0       20.3
# 45               Vermont           29.0       23.6
# 46              Virginia           29.0       23.8
# 47            Washington           29.0       21.9
# 48         West Virginia           69.0       20.4
# 49             Wisconsin          100.0       20.5
# 50               Wyoming          100.0       20.2

# %%
new_act_17_cols = {
    'State':"state",
    "Participation": "act_participation_17",
    "Composite": "act_composite_17"
}
act_17.rename(columns =new_act_17_cols, inplace=True)

# %%
new_act_18_cols = {
    'State':"state",
    "Participation": "act_participation_18",
    "Composite": "act_composite_18"
}
act_18.rename(columns=new_act_18_cols, inplace=True)

# %%
new_sat_17_cols = {
    'State':"state",
    "act_participation_17": "sat_participation_17",
    "Total": "sat_score_17"
}
sat_17.rename(columns=new_sat_17_cols, inplace=True)

# %%
new_sat_18_cols = {
    'State':"state",
    "act_participation_18": "sat_participation_18",
    "Total": "sat_score_18"
}
sat_18.rename(columns = new_sat_18_cols, inplace=True)

# %%
sat_17
# Out:
#                    state  sat_participation_17  sat_score_17
# 0                Alabama                   5.0        1165.0
# 1                 Alaska                  38.0        1080.0
# 2                Arizona                  30.0        1116.0
# 3               Arkansas                   3.0        1208.0
# 4             California                  53.0        1055.0
# 5               Colorado                  11.0        1201.0
# 6            Connecticut                 100.0        1041.0
# 7               Delaware                 100.0         996.0
# 8   District of Columbia                 100.0         950.0
# 9                Florida                  83.0        1017.0
# 10               Georgia                  61.0        1050.0
# 11                Hawaii                  55.0        1085.0
# 12                 Idaho                  93.0        1005.0
# 13              Illinois                   9.0        1115.0
# 14               Indiana                  63.0        1074.0
# 15                  Iowa                   2.0        1275.0
# 16                Kansas                   4.0        1260.0
# 17              Kentucky                   4.0        1247.0
# 18             Louisiana                   4.0        1198.0
# 19                 Maine                  95.0        1012.0
# 20              Maryland                  69.0        1060.0
# 21         Massachusetts                  76.0        1107.0
# 22              Michigan                 100.0        1005.0
# 23             Minnesota                   3.0        1295.0
# 24           Mississippi                   2.0        1242.0
# 25              Missouri                   3.0        1271.0
# 26               Montana                  10.0        1196.0
# 27              Nebraska                   3.0        1253.0
# 28                Nevada                  26.0        1116.0
# 29         New Hampshire                  96.0        1052.0
# 30            New Jersey                  70.0        1056.0
# 31            New Mexico                  11.0        1138.0
# 32              New York                  67.0        1052.0
# 33        North Carolina                  49.0        1081.0
# 34          North Dakota                   2.0        1256.0
# 35                  Ohio                  12.0        1149.0
# 36              Oklahoma                   7.0        1047.0
# 37                Oregon                  43.0        1108.0
# 38          Pennsylvania                  65.0        1071.0
# 39          Rhode Island                  71.0        1062.0
# 40        South Carolina                  50.0        1064.0
# 41          South Dakota                   3.0        1216.0
# 42             Tennessee                   5.0        1228.0
# 43                 Texas                  62.0        1020.0
# 44                  Utah                   3.0        1238.0
# 45               Vermont                  60.0        1114.0
# 46              Virginia                  65.0        1102.0
# 47            Washington                  64.0        1075.0
# 48         West Virginia                  14.0        1086.0
# 49             Wisconsin                   3.0        1291.0
# 50               Wyoming                   3.0        1230.0

# %%
sat_17.sort_values(by=['state'], inplace=True)
act_18.sort_values(by=['state'], inplace=True)
act_17.sort_values(by=['state'], inplace=True)
sat_18.sort_values(by=['state'], inplace=True)

# %%
sat_17 = sat_17.reset_index(drop=True)
sat_18 = sat_18.reset_index(drop=True)
act_17 = act_17.reset_index(drop=True)
act_18 = act_18.reset_index(drop=True)

# %%
# Out:
#                    state  act_participation_18  act_composite_18
# 0                Alabama                 100.0              19.1
# 1                 Alaska                  33.0              20.8
# 2                Arizona                  66.0              19.2
# 3               Arkansas                 100.0              19.4
# 4             California                  27.0              22.7
# 5               Colorado                  30.0              23.9
# 6            Connecticut                  26.0              25.6
# 7               Delaware                  17.0              23.8
# 8   District of Columbia                  32.0              23.6
# 9                Florida                  66.0              19.9
# 10               Georgia                  53.0              21.4
# 11                Hawaii                  89.0              18.9
# 12                 Idaho                  36.0              22.3
# 13              Illinois                  43.0              23.9
# 14               Indiana                  32.0              22.5
# 15                  Iowa                  68.0              21.8
# 16                Kansas                  71.0              21.6
# 17              Kentucky                 100.0              20.2
# 18             Louisiana                 100.0              19.2
# 19                 Maine                   7.0              24.0
# 20              Maryland                  31.0              22.5
# 21         Massachusetts                  25.0              25.5
# 22              Michigan                  22.0              24.2
# 23             Minnesota                  99.0              21.3
# 24           Mississippi                 100.0              18.6
# 25              Missouri                 100.0              20.0
# 26               Montana                 100.0              20.0
# 27              Nebraska                 100.0              20.1
# 28                Nevada                 100.0              17.7
# 29         New Hampshire                  16.0              25.1
# 30            New Jersey                  31.0              23.7
# 31            New Mexico                  67.0              19.4
# 32              New York                  27.0              24.5
# 33        North Carolina                 100.0              19.1
# 34          North Dakota                  98.0              20.3
# 35                  Ohio                 100.0              20.3
# 36              Oklahoma                 100.0              19.3
# 37                Oregon                  42.0              21.3
# 38          Pennsylvania                  20.0              23.5
# 39          Rhode Island                  15.0              24.2
# 40        South Carolina                 100.0              18.3
# 41          South Dakota                  77.0              21.9
# 42             Tennessee                 100.0              19.6
# 43                 Texas                  45.0              20.7
# 44                  Utah                 100.0              20.4
# 45               Vermont                  24.0              24.1
# 46              Virginia                  24.0              23.9
# 47            Washington                  24.0              22.2
# 48         West Virginia                  65.0              20.3
# 49             Wisconsin                 100.0              20.5
# 50               Wyoming                 100.0              20.0

# %%
sat_act_17 = pd.merge(sat_17, act_17, left_index=True, on = 'state' , how='outer')
sat_act_17.head()
# Out:
#         state  sat_participation_17  sat_score_17  act_participation_17  \
# 0     Alabama                   5.0        1165.0                 100.0
# 1      Alaska                  38.0        1080.0                  65.0
# 2     Arizona                  30.0        1116.0                  62.0
# 3    Arkansas                   3.0        1208.0                 100.0
# 4  California                  53.0        1055.0                  31.0
#
#    act_composite_17
# 0              19.2
# 1              19.8
# 2              19.7
# 3              19.4
# 4              22.8

# %%
sat_act_18 = pd.merge(sat_18, act_18, left_index=True, on="state", how="outer")
sat_act_18.head()
# Out:
#         state  sat_participation_18  sat_score_18  act_participation_18  \
# 0     Alabama                   6.0        1166.0                 100.0
# 1      Alaska                  43.0        1106.0                  33.0
# 2     Arizona                  29.0        1149.0                  66.0
# 3    Arkansas                   5.0        1169.0                 100.0
# 4  California                  60.0        1076.0                  27.0
#
#    act_composite_18
# 0              19.1
# 1              20.8
# 2              19.2
# 3              19.4
# 4              22.7

# %%
df = pd.merge(sat_act_17,sat_act_18, left_index=True, on = 'state' , how='outer')
df.head()
df.shape
# Out:
# (51, 9)

# %%
df.to_csv('./data/sat_act_2017_2018.csv', encoding='utf-8', index = False)

# %%
plt.xlabel('df')
# Out:
# Text(0.5, 0, 'df')

# %%
sns.barplot(data=df, x='state', y= 'act_composite_18')
plt.xlabel('state')
# Out:
# Text(0.5, 0, 'state')

# %%
sns.distplot(df['act_participation_17'], bins=10, kde=False)

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x='sat_score_17',y='sat_participation_17', data=df)

# %%
df
# Out:
#                    state  sat_participation_17  sat_score_17  \
# 0                Alabama                   5.0        1165.0
# 1                 Alaska                  38.0        1080.0
# 2                Arizona                  30.0        1116.0
# 3               Arkansas                   3.0        1208.0
# 4             California                  53.0        1055.0
# 5               Colorado                  11.0        1201.0
# 6            Connecticut                 100.0        1041.0
# 7               Delaware                 100.0         996.0
# 8   District of Columbia                 100.0         950.0
# 9                Florida                  83.0        1017.0
# 10               Georgia                  61.0        1050.0
# 11                Hawaii                  55.0        1085.0
# 12                 Idaho                  93.0        1005.0
# 13              Illinois                   9.0        1115.0
# 14               Indiana                  63.0        1074.0
# 15                  Iowa                   2.0        1275.0
# 16                Kansas                   4.0        1260.0
# 17              Kentucky                   4.0        1247.0
# 18             Louisiana                   4.0        1198.0
# 19                 Maine                  95.0        1012.0
# 20              Maryland                  69.0        1060.0
# 21         Massachusetts                  76.0        1107.0
# 22              Michigan                 100.0        1005.0
# 23             Minnesota                   3.0        1295.0
# 24           Mississippi                   2.0        1242.0
# 25              Missouri                   3.0        1271.0
# 26               Montana                  10.0        1196.0
# 27              Nebraska                   3.0        1253.0
# 28                Nevada                  26.0        1116.0
# 29         New Hampshire                  96.0        1052.0
# 30            New Jersey                  70.0        1056.0
# 31            New Mexico                  11.0        1138.0
# 32              New York                  67.0        1052.0
# 33        North Carolina                  49.0        1081.0
# 34          North Dakota                   2.0        1256.0
# 35                  Ohio                  12.0        1149.0
# 36              Oklahoma                   7.0        1047.0
# 37                Oregon                  43.0        1108.0
# 38          Pennsylvania                  65.0        1071.0
# 39          Rhode Island                  71.0        1062.0
# 40        South Carolina                  50.0        1064.0
# 41          South Dakota                   3.0        1216.0
# 42             Tennessee                   5.0        1228.0
# 43                 Texas                  62.0        1020.0
# 44                  Utah                   3.0        1238.0
# 45               Vermont                  60.0        1114.0
# 46              Virginia                  65.0        1102.0
# 47            Washington                  64.0        1075.0
# 48         West Virginia                  14.0        1086.0
# 49             Wisconsin                   3.0        1291.0
# 50               Wyoming                   3.0        1230.0
#
#     act_participation_17  act_composite_17  sat_participation_18  \
# 0                  100.0              19.2                   6.0
# 1                   65.0              19.8                  43.0
# 2                   62.0              19.7                  29.0
# 3                  100.0              19.4                   5.0
# 4                   31.0              22.8                  60.0
# 5                  100.0              20.8                 100.0
# 6                   31.0              25.2                 100.0
# 7                   18.0              24.1                 100.0
# 8                   32.0              24.2                  92.0
# 9                   73.0              19.8                  56.0
# 10                  55.0              21.4                  70.0
# 11                  90.0              19.0                  56.0
# 12                  38.0              22.3                 100.0
# 13                  93.0              21.4                  99.0
# 14                  35.0              22.6                  63.0
# 15                  67.0              21.9                   3.0
# 16                  73.0              21.7                   4.0
# 17                 100.0              20.0                   4.0
# 18                 100.0              19.5                   4.0
# 19                   8.0              24.3                  99.0
# 20                  28.0              23.6                  76.0
# 21                  29.0              25.4                  80.0
# 22                  29.0              24.1                 100.0
# 23                 100.0              21.5                   4.0
# 24                 100.0              18.6                   3.0
# 25                 100.0              20.4                   4.0
# 26                 100.0              20.3                  10.0
# 27                  84.0              21.4                   3.0
# 28                 100.0              17.8                  23.0
# 29                  18.0              25.5                  96.0
# 30                  34.0              23.9                  82.0
# 31                  66.0              19.7                  16.0
# 32                  31.0              24.2                  79.0
# 33                 100.0              19.1                  52.0
# 34                  98.0              20.3                   2.0
# 35                  75.0              22.0                  18.0
# 36                 100.0              19.4                   8.0
# 37                  40.0              21.8                  48.0
# 38                  23.0              23.7                  70.0
# 39                  21.0              24.0                  97.0
# 40                 100.0              18.7                  55.0
# 41                  80.0              21.8                   3.0
# 42                 100.0              19.8                   6.0
# 43                  45.0              20.7                  66.0
# 44                 100.0              20.3                   4.0
# 45                  29.0              23.6                  64.0
# 46                  29.0              23.8                  68.0
# 47                  29.0              21.9                  69.0
# 48                  69.0              20.4                  28.0
# 49                 100.0              20.5                   3.0
# 50                 100.0              20.2                   3.0
#
#     sat_score_18  act_participation_18  act_composite_18
# 0         1166.0                 100.0              19.1
# 1         1106.0                  33.0              20.8
# 2         1149.0                  66.0              19.2
# 3         1169.0                 100.0              19.4
# 4         1076.0                  27.0              22.7
# 5         1025.0                  30.0              23.9
# 6         1053.0                  26.0              25.6
# 7          998.0                  17.0              23.8
# 8          977.0                  32.0              23.6
# 9         1099.0                  66.0              19.9
# 10        1064.0                  53.0              21.4
# 11        1010.0                  89.0              18.9
# 12        1001.0                  36.0              22.3
# 13        1019.0                  43.0              23.9
# 14        1074.0                  32.0              22.5
# 15        1265.0                  68.0              21.8
# 16        1265.0                  71.0              21.6
# 17        1248.0                 100.0              20.2
# 18        1210.0                 100.0              19.2
# 19        1013.0                   7.0              24.0
# 20        1080.0                  31.0              22.5
# 21        1125.0                  25.0              25.5
# 22        1011.0                  22.0              24.2
# 23        1298.0                  99.0              21.3
# 24        1236.0                 100.0              18.6
# 25        1262.0                 100.0              20.0
# 26        1198.0                 100.0              20.0
# 27        1252.0                 100.0              20.1
# 28        1140.0                 100.0              17.7
# 29        1063.0                  16.0              25.1
# 30        1094.0                  31.0              23.7
# 31        1093.0                  67.0              19.4
# 32        1068.0                  27.0              24.5
# 33        1098.0                 100.0              19.1
# 34        1283.0                  98.0              20.3
# 35        1099.0                 100.0              20.3
# 36        1062.0                 100.0              19.3
# 37        1117.0                  42.0              21.3
# 38        1086.0                  20.0              23.5
# 39        1018.0                  15.0              24.2
# 40        1070.0                 100.0              18.3
# 41        1240.0                  77.0              21.9
# 42        1231.0                 100.0              19.6
# 43        1032.0                  45.0              20.7
# 44        1010.0                 100.0              20.4
# 45        1120.0                  24.0              24.1
# 46        1117.0                  24.0              23.9
# 47        1081.0                  24.0              22.2
# 48         999.0                  65.0              20.3
# 49        1294.0                 100.0              20.5
# 50        1257.0                 100.0              20.0

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True)
